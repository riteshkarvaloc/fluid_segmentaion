# %%
from PIL import Image
import numpy as np

# %%
img1 = Image.open('AMRD14.jpeg')
img1_arr = np.asarray(img1)
img2 = Image.open('images/AMRD14-segmentation.jpeg')
img2_arr = np.asarray(img2)

# %%
img1_arr.shape, img2_arr.shape
# Out:
# ((586, 879, 3), (586, 879, 3))

# %%
images = [img1, img2]
widths, heights = zip(*(i.size for i in images))
total_width = sum(widths)
max_height = max(heights)

new_im = Image.new('RGB', (total_width, max_height))

x_offset = 0
for im in images:
  new_im.paste(im, (x_offset,0))
  x_offset += im.size[0]

# %%
new_im
# Out:
# <PIL.Image.Image image mode=RGB size=1758x586 at 0x7FF22A5F3A20>
